# %%
import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter 
import scipy.spatial
import scipy
import json
from matplotlib import cm as CM
from image import load_data
from model import CSRNet
import torch
# %matplotlib inline

# %%
#this is borrowed from https://github.com/davideverona/deep-crowd-counting_crowdnet
def gaussian_filter_density(gt):
    print(gt.shape)
    density = np.zeros_like(gt, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(list(zip(np.nonzero(gt)[1], np.nonzero(gt)[0])))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print('generate density...')
    for i, pt in enumerate(pts):
        pt2d = np.zeros_like(gt, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print('done.')
    return density

# %%
#set the root to the Shanghai dataset you download
root = '/home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset'

# %%
#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A_final/train_data','images')
part_A_test = os.path.join(root,'part_A_final/test_data','images')
part_B_train = os.path.join(root,'part_B_final/train_data','images')
part_B_test = os.path.join(root,'part_B_final/test_data','images')
path_sets = [part_A_train,part_A_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print (img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
# Out:
# c/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_32.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_57.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_21.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_146.jpg
# (611, 767)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_128.jpg
# (424, 636)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_46.jpg
# (680, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_176.jpg
# (400, 570)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_13.jpg
# (587, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_2.jpg
# (684, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_29.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_164.jpg
# (265, 701)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_43.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_178.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_11.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_170.jpg
# (687, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_140.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_172.jpg
# (350, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_153.jpg
# (400, 600)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_63.jpg
# (655, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_59.jpg
# (350, 860)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_78.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_25.jpg
# (681, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_22.jpg
# (540, 720)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_65.jpg
# (400, 682)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_74.jpg
# (742, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_113.jpg
# (506, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_52.jpg
# (284, 550)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_16.jpg
# (419, 536)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_108.jpg
# (552, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_4.jpg
# (334, 500)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_161.jpg
# (540, 960)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_94.jpg
# (276, 460)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_92.jpg
# (540, 833)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_24.jpg
# (633, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_82.jpg
# (370, 545)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_85.jpg
# (577, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_18.jpg
# (681, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_168.jpg
# (688, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_181.jpg
# (681, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_66.jpg
# (1024, 743)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_17.jpg
# (508, 997)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_147.jpg
# (433, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_3.jpg
# (427, 640)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_97.jpg
# (669, 1000)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_182.jpg
# (688, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_20.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_44.jpg
# (767, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_129.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_123.jpg
# (276, 460)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_68.jpg
# (607, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_118.jpg
# (676, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_49.jpg
# (464, 634)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_12.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_166.jpg
# (540, 960)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_34.jpg
# (200, 300)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_10.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_67.jpg
# (600, 800)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_99.jpg
# (480, 640)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_169.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_62.jpg
# (480, 624)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_150.jpg
# (428, 652)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_148.jpg
# (434, 650)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_133.jpg
# (378, 810)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_28.jpg
# (697, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_98.jpg
# (373, 561)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_73.jpg
# (681, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_103.jpg
# (666, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_120.jpg
# (609, 469)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_19.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_27.jpg
# (781, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_174.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_5.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_121.jpg
# (684, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_149.jpg
# (749, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_173.jpg
# (713, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_80.jpg
# (690, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_162.jpg
# (448, 610)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_151.jpg
# (437, 624)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_9.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_72.jpg
# (480, 640)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_58.jpg
# (706, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_143.jpg
# (432, 550)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_100.jpg
# (409, 902)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_14.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_71.jpg
# (763, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_136.jpg
# (224, 400)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_26.jpg
# (293, 450)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_165.jpg
# (681, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_33.jpg
# (577, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_154.jpg
# (324, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_64.jpg
# (443, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_50.jpg
# (1024, 992)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_179.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_135.jpg
# (224, 400)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_145.jpg
# (367, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_38.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_70.jpg
# (417, 600)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_6.jpg
# (687, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_163.jpg
# (500, 649)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_132.jpg
# (403, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_125.jpg
# (659, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_87.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_51.jpg
# (667, 1000)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_56.jpg
# (411, 620)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_126.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_105.jpg
# (661, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_36.jpg
# (424, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_86.jpg
# (741, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_110.jpg
# (684, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_61.jpg
# (398, 598)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_39.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_96.jpg
# (334, 540)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_77.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_81.jpg
# (343, 743)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_69.jpg
# (308, 498)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_130.jpg
# (547, 795)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_31.jpg
# (615, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_104.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_47.jpg
# (350, 600)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_159.jpg
# (580, 882)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_158.jpg
# (428, 594)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_37.jpg
# (669, 1000)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_15.jpg
# (333, 500)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_138.jpg
# (438, 293)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_127.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_156.jpg
# (552, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_160.jpg
# (359, 478)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_89.jpg
# (534, 800)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_88.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_8.jpg
# (684, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_76.jpg
# (450, 676)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_114.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_83.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_144.jpg
# (398, 728)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_137.jpg
# (299, 449)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_124.jpg
# (448, 640)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_171.jpg
# (687, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_180.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_139.jpg
# (511, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_111.jpg
# (683, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_106.jpg
# (476, 1001)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_42.jpg
# (768, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_112.jpg
# (720, 960)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_23.jpg
# (942, 1024)
# generate density...
# done.
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_134.jpg
# (790, 1024)
# generate density...
# done.

# %%
#now see a sample from ShanghaiA
plt.imshow(Image.open(img_paths[0]));

# %%
gt_file = h5py.File(img_paths[0].replace('.jpg','.h5').replace('images','ground_truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet);

# %%
np.sum(groundtruth)# don't mind this slight variation
# Out:
# 188.74593

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print(img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter(k,15)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
# Out:
# Tech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_4.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_203.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_161.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_94.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_92.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_294.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_237.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_24.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_82.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_85.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_18.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_168.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_181.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_66.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_197.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_251.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_17.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_263.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_147.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_201.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_3.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_97.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_182.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_234.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_20.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_224.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_221.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_44.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_129.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_123.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_68.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_118.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_268.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_49.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_12.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_166.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_34.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_10.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_67.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_99.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_169.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_280.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_62.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_276.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_261.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_228.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_150.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_216.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_208.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_231.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_148.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_188.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_133.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_238.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_28.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_258.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_98.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_302.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_183.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_264.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_73.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_103.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_120.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_236.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_19.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_212.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_220.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_193.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_305.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_27.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_315.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_309.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_174.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_5.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_121.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_149.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_173.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_254.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_242.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_80.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_162.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_151.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_245.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_9.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_72.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_58.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_296.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_219.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_239.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_143.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_290.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_293.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_225.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_265.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_100.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_14.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_71.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_136.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_26.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_247.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_165.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_33.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_154.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_64.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_50.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_235.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_179.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_135.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_191.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_145.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_241.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_38.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_70.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_6.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_163.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_132.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_125.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_298.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_249.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_211.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_186.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_87.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_287.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_230.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_51.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_250.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_56.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_126.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_214.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_105.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_207.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_36.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_226.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_86.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_110.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_218.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_61.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_39.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_206.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_96.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_77.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_311.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_81.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_69.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_130.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_257.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_31.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_246.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_233.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_104.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_47.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_159.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_270.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_158.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_37.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_15.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_138.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_196.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_127.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_156.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_292.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_160.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_89.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_244.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_88.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_8.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_76.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_255.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_312.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_213.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_114.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_272.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_297.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_252.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_83.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_277.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_144.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_137.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_124.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_210.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_316.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_171.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_180.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_139.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_111.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_198.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_278.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_240.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_199.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_307.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_106.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_42.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_291.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_112.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_23.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_223.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_134.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_267.jpg
# /home/uluyac/Downloads/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/test_data/images/IMG_284.jpg
